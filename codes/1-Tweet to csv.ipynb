# %%
from TwitterSearch import *
try:
    tso = TwitterSearchOrder() # create a TwitterSearchOrder object
    tso.set_keywords(['blacklivesmatter']) # let's define all words we would like to have a look for
    tso.set_language('en') # we want to see English tweets only
    tso.set_include_entities(False) # and don't give us all those entity information

    # it's about time to create a TwitterSearch object with our secret tokens
    ts = TwitterSearch(
        consumer_key = '67HE5RIMUhTsbpt3oXhFq9DiP',
        consumer_secret = 'LtLv7toJoILSHDWO1kngQajbsubXp4o6U3jQiMUCt7jh5UlvhW',
        access_token = '3945428712-SPkU6GuOtSMeoO3znfeMDl0woutrlcnGdOXMgLa',
        access_token_secret = '7wQ7fDo9S1ZF25wCyrGlioJaMfqMMQwewEFfVaqzKqo1l'
     )

     # this is where the fun actually starts :)
    for tweet in ts.search_tweets_iterable(tso):
        print( '@%s tweeted: %s' % ( tweet['user']['screen_name'], tweet['text'], tweet['retweeted'] ) )

        
except TwitterSearchException as e: # take care of all those ugly errors if there are some
    print(e)



def format_articles(unformatted_docs):
    formatted = []
    for tweet in unformatted_docs:
        dic = {}
        dic['user'] = tweet['user']['screen_name']
        dic['text'] = tweet['text'].encode("utf8")
        formatted.append(dic)
    return(formatted) 

all_formatted = format_articles(ts.search_tweets_iterable(tso))

import csv
keys = all_formatted[1].keys()

with open('blacklivesmatter2.csv', 'w') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(all_formatted)
# Out:
# @SundayOmony tweeted: ANOTHER VIEW OF @YOUTUBE FT. @TJSOTOMAYOR #TommySotomayor
# https://t.co/5WtldeCAP3 #YouTube #YTCreators #BLM… https://t.co/ec9osIpnNg
# @FollowSmoke2 tweeted: @georgid63 @RodLurie The KKK has never caused as much destruction as #BlackLivesMatter has
# @theclaytyler tweeted: RT @DRoOakland: Written by Justin C. Cohen #BlackLivesMatter #AltonSterling https://t.co/oIZOxxhfCj
# @GAYPRESlDENT tweeted: RT @benandjerrys: Is systemic racism a thing? It sure is and these stats prove it &gt;&gt; https://t.co/IrkJyIJ2nW #BlackLivesMatter https://t.co…
# @redsonic17 tweeted: RT @LucidHurricane_: Nobody is #MoreElectableThanTrump for the AA community
# #BlackLivesMatter to @realDonaldTrump https://t.co/tbpcVjonZ1
# @ZBeeblebrox42nc tweeted: RT @frankgaffney: How the #BlackLivesMatter movement has exploited a non-cause. Truth behind #BLM , its origins &amp; funding https://t.co/vvOk…
# ...
